# %%
from PIL import Image

# %%
green = Image.open("california.png")

# %%
green
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=715x811 at 0x7FDF9CE4D780>

# %%
factor = 10
green = green.resize((green.size[0]//factor, green.size[1]//factor), Image.BICUBIC)
green = green.resize((green.size[0]*factor, green.size[1]*factor), Image.NEAREST)

# %%
green
# Out:
# <PIL.Image.Image image mode=RGB size=710x810 at 0x7FDF9CE4DC50>

# %%
print(green.size[0]//factor,green.size[1]//factor)
