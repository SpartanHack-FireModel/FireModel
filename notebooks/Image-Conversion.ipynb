# %%
from PIL import Image

# %%
green = Image.open("green.png")

# %%
green
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1124x758 at 0x7FD874140470>

# %%
factor = 9
green = green.resize((green.size[0]//factor, green.size[1]//factor), Image.NEAREST)
green = green.resize((green.size[0]*factor, green.size[1]*factor), Image.NEAREST)

# %%
green
# Out:
# <PIL.Image.Image image mode=RGB size=1116x756 at 0x7FD874147898>
