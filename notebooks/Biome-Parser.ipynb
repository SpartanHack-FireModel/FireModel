# %%
from PIL import Image

# %%
veg = Image.open('veg.jpg')

# %%
veg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1063x1500 at 0x7F50296B7B00>

# %%
factor = 10
veg = veg.resize((veg.size[0]//factor, veg.size[1]//factor), Image.BICUBIC)
veg = veg.resize((veg.size[0]*factor, veg.size[1]*factor), Image.BICUBIC)
veg = veg.resize((veg.size[0]//factor, veg.size[1]//factor), Image.NEAREST)
veg = veg.resize((veg.size[0]*factor, veg.size[1]*factor), Image.NEAREST)

# %%
veg
# Out:
# <PIL.Image.Image image mode=RGB size=1060x1500 at 0x7F50296B7B38>
